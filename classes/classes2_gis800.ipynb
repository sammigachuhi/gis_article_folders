# %% [markdown]
# # Introduction
# Classes are our biggest nightmare. However, next to `for` loops and `functions`, `classes` are the next critical component of python you've got to learn. But mastering them can be definitely challenging. In python, everything is an [object](https://www.javatpoint.com/what-is-an-object-in-python). This includes variables, functions, lists, tuples, dictionaries and et cetera. So what's the big hullabaloo about classes? Classes help a programmer reuse code. In fact, if all operations were left to loops, we would have lengthy complicated programmes. We assure you that even though classes look like a complicated concept, they actually make life easier than if tens of looping functions were instead used. The [Brilliant](https://brilliant.org/wiki/classes-oop/#:~:text=Classes%20are%20used%20to%20create,a%20mechanism%20of%20reusing%20code.) website splendidly explains what classes are:
#
# *A class is a way of organizing information about a type of data so a programmer can reuse elements when making multiple instances of that data type—for example, if a programmer wanted to make three instances of Car, maybe a BMW, a Ferrari, and a Ford instance. The Car class would allow the programmer to store similar information that is unique to each car (they are different models, and maybe different colors, etc.) and associate the appropriate information with each car.*
#
# To make this concept of classes clearer consider the following simple example:

# %%
# Create a variable called max
max = 24

# %% [markdown]
# The variable `max` is an object. Let's take it as though this is a real life person called 'max' and that his age is 24. Thus the `max` variable, which is by extension also an *object*, is an integer --it is assigned to the value 24. Having seen what a class is, let's introduce what's the relationship between classes and objects. The `class` acts as a blue-print of what the object will look like, and function. Objects on the other hand, are an *instance* of a class. Consider yourself building your dream home. The architect's blueprint shows how every component of the house such as doors, ceilings, floors and windows will be designed. This blueprint containing the design details is what a *class* is to programming. The house, with all its components, acts as our object. Because almost everything in Python follows the Class-Object relationship, it is thus referred to as an **Object Oriented Programming** language.
#
# Classes of objects in python can be known using the `type` function.

# %%
# Get class of the object -max
type(max)
# Out:
# int

# %% [markdown]
# In python, we [create classes]((https://pynative.com/python-classes-and-objects/) using the `class` keyword.

# %%
# Create a Friend Class that shows name, sex and age of your friend!
class Friend():
    """Show simple information about a student."""
    def __init__(self, name, sex, age):
        # Attributes of your friend
        self.name = name
        self.sex = sex
        self.age = age 
        
    def describe(self):
        # Describe to a person your friend's characteristics
        print("My best friend is called ", self.name, " a ", self.sex, "and is ", self.age, " years.")

# %% [markdown]
# What did we just do in the above example? In python, classes are created using the below format. Remember classes act as blueprints, therefore have that in mind as you look at the below code.
#
# ```python
# class class_name:
#     '''This is a docstring. I have created a new class'''
#     def __init__(self, x, y, z)
#     <statement 1>
#     <statement 2>
#     .
#     .
#     <statement N>
# ```
#
# The `def __init__(self, ...)` is a keyword used to create the instance of an object. It is for this reason referred to as a constructor. The argument `self` is a naming convention referring to the current object. Finally, last but not least the statement in docstrings (""" """) is used to describe what the class does. Consider the above sketchy code as the blue print of your house. The statements after the `def__init__(self, ...)` function are the designs for each component of your house such as the sitting room. Let's create a simple blueprint of our friend (don't overthink). We know our friend so much that we can only state the name, sex and age ;). Let's create a class called 'Friend' that will be the blueprint, or rather the framework of our friend.

# %%
# Create a Friend Class that shows name, sex and age of your friend!
class Friend():
    """Show simple information about a student."""
    def __init__(self, name, sex, age):
        # Attributes of your friend
        self.name = name
        self.sex = sex
        self.age = age 
        
    def describe(self):
        # Describe to a person your friend's characteristics
        print("My best friend is called ", self.name, " a ", self.sex, "and is ", self.age, " years.")

# %% [markdown]
# Now that we've created a class of our friend, where do we store the information regarding our friend? We call the information of `name`, `sex` and `age` of our friend as attributes. To create these attributes within (or under) a class, we assign them the prefix `self`. The creation and assignment of attributes to our class is thanks to the `def __init__` function. This function is called everytime an object is created from a class. The creation of objects from classes is called initialization. See the `__init__` from **init**ialization inside `def`.  Finally, all information within our `Friend` class has to be stored in an object just as we stored the integer 24 to the `max` variable. Objects of classes are created using the following convention:
#
# ```python
# <object-name> = <class-name>(<arguments>)
# ```

# %% [markdown]
# Let's try creating an object our `Friend` class. We shall call our friend 'Diana'.

# %%
# Create class of your first friend
friend1 = Friend('Diana', 'Female', '22')

# %% [markdown]
# To describe our friend, we have to use the method `describe(self)` which we had created within the `Friend` class.

# %%
friend1.describe()
# Out:
# My best friend is called  Diana  a  Female and is  22  years.

# %% [markdown]
# Got it? Let's finally make our class look better by tweaking a few things and cross over to spatial matters.

# %%
class Friend():
    """This class describes the name, sex and age of my friend."""
    def __init__(self, name, sex, age):
        # Attributes of your friend
        self.name = name
        self.sex = sex
        self.age = age 
        
    def describe(self):
        # Describe to a person your friend's characteristics
        print("My best friend is: ", "\nName: ", self.name, "\nSex: ", self.sex, "\nAge: ", self.age)
        
friend2 = Friend('Jonathan', 'Male', 25)
friend2.describe()
# Out:
# My best friend is:
# Name:  Jonathan
# Sex:  Male
# Age:  25

# %% [markdown]
# ## Classes in GIS
#
# Let's create a class to display some geometries.

# %%
# Modules to be used in creating the class objects
import pandas as pd
import geopandas as gpd

# %% [markdown]
# Our class will be responsible for creating a dataframe of lon-lat coordinates of a place. The goal is to create a class that creates a geodataframe from the lon-lat coordinates and finally plots a map using the coordinates. In classes, it's best to start simple and progress along. That should be your lesson 101 in `classes` for python!

# %%
# Modules to be used in creating the class objects
import pandas as pd
import geopandas as gpd

class Place():
    """Describe our place and show it"""
    def __init__(self, names,  longitudes, latitudes):
        # Create variables for the names, longitudes and latitudes
        self.names = names
        self.longitudes = longitudes
        self.latitudes = latitudes

    def dataTable(self):
        # Create a dataframe from the above variables of names, longitudes, and latitudes
        self.dataTable = pd.DataFrame({
            'Name': [self.names],
            'Longitude': [self.longitudes], 
            'Latitude': [self.latitudes]})
        
    def showDataFrame(self):
        # Print the dataframe
        print(self.dataTable)

# %% [markdown]
# We shall create an object called `place1` that will assign our target lon-lat coordinates to the `Place` class.

# %%
# Create an object of Place class called place1
place1 = Place("vasco", 40.1276701, -3.2236304)

# Create a dataframe from the coordinates of place1
place1.dataTable()

# %% [markdown]
# In the above cell, we created an object instance of `Place` class, and used the `dataTable` method to create a dataframe from the given coordinates. Next we shall use the `showDataFrame` method to print out the datatable we had created.

# %%
place1.showDataFrame()
# Out:
#     Name  Longitude  Latitude
# 0  vasco   40.12767  -3.22363

# %% [markdown]
# ## Inheritance
#
# As if classes don't look complicated enough, we shall introduce a concept known as **inheritance**. Inheritance is simply a code picking up the characteristics of a different class, albeit to perform a similar or totally different function. Consider that you are a Parent. I know, some of us are yet to be :). Your child will obviously inherit some of your qualities, perhaps eyes, voice, complexion teeth and personality (maybe!). Now in the physique of your child, the body already has some components of your qualities within his/her DNA. The same applies to Object Oriented Programming.
#
# For our case, we shall create a class called `GeoSpatial` that inherits all the properties of the `Place` class, but uses these properties to create a geodataframe. The `Place` class simply stops at the creation of a dataframe. The `GeoSpatial` class will go beyond this. Consider the `Place` class as the parent, and the `Geospatial` class as the child.

# %%
# Modules to be used in creating the class objects
import pandas as pd
import geopandas as gpd

class Place():
    """Describe our place and show it"""
    def __init__(self, names,  longitudes, latitudes): # Everything in the brackets is an argument. Self is always the first argument in a class method defintion
        self.names = names
        self.longitudes = longitudes
        self.latitudes = latitudes

    def dataTable(self):
        self.dataTable = pd.DataFrame({
            'Name': [self.names],
            'Longitude': [self.longitudes], 
            'Latitude': [self.latitudes]})
        
    def showDataFrame(self):
        print(self.dataTable)
    
class GeoSpatial(Place):
    # This class is to take the arguments from Place class and use them to create a geodataframe
    def __init__(self, names, longitudes, latitudes, crs):
        super().__init__(names, longitudes, latitudes)
        self.crs = crs
        print("Name: ", self.names, "\nLongitudes: ", self.longitudes, "\nLatitudes: ", self.latitudes, "\nCRS: ", crs)
            
    def geoDataFrame(self):
        # Create a geodataframe
        self.geoDataFrame = gpd.GeoDataFrame(self.names, 
                         geometry=gpd.points_from_xy(self.longitudes, self.latitudes), 
                         crs=crs)
        print(self.geoDataFrame)

# %% [markdown]
# Look at the `GeoSpatial` class a little closer. We have introduced the `def __init__()` function to initialize the same attributes as those of `Place` class. We have introduced another function, the `super()` function. The purpose of this latter function is to inherit the same instance attributes used in `Place` class to `GeoSpatial` class.

# %%
# Create an object place1 for the Geospatial class
place1 = GeoSpatial("vasco", 40.1276701, -3.2236304, "EPSG:4326")
# Out:
# Name:  vasco
# Longitudes:  40.1276701
# Latitudes:  -3.2236304
# CRS:  EPSG:4326

# %%
# Create a second object for Geospatial class --place2
place2 = GeoSpatial("gedi", 39.9623916, -3.334307, 'EPSG:4326')
# Out:
# Name:  gedi
# Longitudes:  39.9623916
# Latitudes:  -3.334307
# CRS:  EPSG:4326

# %% [markdown]
# That looks easy enough, how about if we have two variables? Can our fancy `Place` class handle the load?

# %%
# Testing our classes with a list of objects
place_names = ['Vasco', 'Gedi']
place_longitudes = [40.1276701, 39.9623916]
place_latitudes = [-3.2236304, -3.334307]
places_crs = "EPSG:4326"

# %%
many_places = Place(place_names, place_longitudes, place_latitudes)
many_places.dataTable()
many_places.showDataFrame()
# Out:
#             Name                 Longitude                 Latitude
# 0  [Vasco, Gedi]  [40.1276701, 39.9623916]  [-3.2236304, -3.334307]

# %% [markdown]
# The above dataframe resulting from the `showDataFRame` method will spell doom if we want to plot a map from that information. Let's try and fix the issue by removing the square brackets from the `dataTable` method.

# %%
# Modules to be used in creating the class objects
import pandas as pd
import geopandas as gpd

class Place():
    """Describe our place and show it"""
    def __init__(self, names,  longitudes, latitudes): # Everything in the brackets is an argument. Self is always the first argument in a class method defintion
        self.names = names
        self.longitudes = longitudes
        self.latitudes = latitudes

    def dataTable(self):
        self.dataTable = pd.DataFrame({
            'Name': self.names,
            'Longitude': self.longitudes, 
            'Latitude': self.latitudes})
        
    def showDataFrame(self):
        print(self.dataTable)
    
class GeoSpatial(Place):
    # This class is to take the arguments from Place class and use them to create a geodataframe
    def __init__(self, names, longitudes, latitudes, crs):
        super().__init__(names, longitudes, latitudes)
        self.crs = crs
        print("Name: ", self.names, "\nLongitudes: ", self.longitudes, "\nLatitudes: ", self.latitudes, "\nCRS: ", crs)
            
    def geoDataFrame(self):
        self.geoDataFrame = gpd.GeoDataFrame(self.names, 
                         geometry=gpd.points_from_xy(self.longitudes, self.latitudes), 
                         crs=self.crs)
        print(self.geoDataFrame)

# %%
place_names = ['Vasco', 'Gedi']
place_longitudes = [40.1276701, 39.9623916]
place_latitudes = [-3.2236304, -3.334307]
places_crs = "EPSG:4326"

# %%
many_places = Place(place_names, place_longitudes, place_latitudes)
many_places.dataTable()
many_places.showDataFrame()
# Out:
#     Name  Longitude  Latitude
# 0  Vasco  40.127670 -3.223630
# 1   Gedi  39.962392 -3.334307

# %% [markdown]
# Now everything is working perfectly. After our correction, it seems that our class will only work if lon-Lat coordinates are inside a list, like so:

# %%
# Test the Class Place again after having removed square brackets from Longitude and Latitude variables
places_test = Place("vasco", [40.1276701], [-3.2236304]) # Place the lon-lat coordinate values into lists
# Create a dataframe from the coordinates of place1
places_test.dataTable()
places_test.showDataFrame()
# Out:
#     Name  Longitude  Latitude
# 0  vasco   40.12767  -3.22363

# %%
# Test the class Place again using lists only
places_test2 = Place(['vasco', 'gedi'], [40.127670, 39.962392], [-3.223630, -3.334307])
places_test2.dataTable()
places_test2.showDataFrame()
# Out:
#     Name  Longitude  Latitude
# 0  vasco  40.127670 -3.223630
# 1   gedi  39.962392 -3.334307

# %% [markdown]
# Ok. So far so good. However, we need to give our `GeoSpatial` class some life's lessons. This is the class that inherits from `Place`. Let's see if it works.

# %%
many_places = GeoSpatial(place_names, place_longitudes, place_latitudes, places_crs)
many_places.geoDataFrame()
# Out:
# Name:  ['Vasco', 'Gedi']
# Longitudes:  [40.1276701, 39.9623916]
# Latitudes:  [-3.2236304, -3.334307]
# CRS:  EPSG:4326
#        0                   geometry
# 0  Vasco  POINT (40.12767 -3.22363)
# 1   Gedi  POINT (39.96239 -3.33431)

# %% [markdown]
# Our `geoDataFrame()` method works but it needs some tweaking. It gives out two dataframes yet we are only interested in the second better looking dataframe. We can sort this 'small' anomaly by relegating the printing of a neater dataframe to a different function, say `showDataFrame` function. Remember, we are perfecting as we go and trial-error-correct is the *sine-qua-non* in python classes. Next step ist make our class be able to create webmaps. Is that too much of a stretch for today's lesson? One more module shall be needed to enable our class draw the webmap, and this is the `contextily` module.

# %%
# Modules to be used in creating the class objects
import pandas as pd
import geopandas as gpd

# Classes using contextily
import contextily as cx
import matplotlib.pyplot as plt

class Place():
    """Describe our place and show it"""
    def __init__(self, names,  longitudes, latitudes): # Everything in the brackets is an argument. Self is always the first argument in a class method defintion
        self.names = names
        self.longitudes = longitudes
        self.latitudes = latitudes

    def dataTable(self):
        self.dataTable = pd.DataFrame({
            'Name': self.names,
            'Longitude': self.longitudes, 
            'Latitude': self.latitudes})
        
    def showDataFrame(self):
        print(self.dataTable)
    
class GeoSpatial(Place):
    def __init__(self, names, longitudes, latitudes, crs):
        # This class is to take the arguments from Place class and use them to create a geodataframe
        super().__init__(names, longitudes, latitudes)
        self.crs = crs
        print("Name: ", self.names, "\nLongitudes: ", self.longitudes, "\nLatitudes: ", self.latitudes, "\nCRS: ", crs)
            
    def geoDataFrame(self):
        self.geoDataFrame = gpd.GeoDataFrame(self.names, 
                         geometry=gpd.points_from_xy(self.longitudes, self.latitudes), 
                         crs= self.crs)
        
    def showGeoDataFrame(self):
        print(self.geoDataFrame)
        
    def webMap(self):
        fig, ax = plt.subplots(figsize=(8, 6))
        webMap = self.geoDataFrame.plot(ax=ax)
        # for name, lon, lat in zip(self.names, self.longitudes, self.latitudes):
            # self.geoDataFrame.annotate(name, xy=(lon, lat), xytext=(-4, 2), textcoords='offset points')
        cx.add_basemap(ax, crs=self.geoDataFrame.crs, source=cx.providers.OpenStreetMap.Mapnik)

# %% [markdown]
# Note that we have relegated the work of printing a geodataframe to the `showGeoDataFrame` method. Let's print our geodataframe and plot that webmap.

# %%
# Create GeoDataFrame
many_places = GeoSpatial(place_names, place_longitudes, place_latitudes, places_crs)
many_places.geoDataFrame()
# Out:
# Name:  ['Vasco', 'Gedi']
# Longitudes:  [40.1276701, 39.9623916]
# Latitudes:  [-3.2236304, -3.334307]
# CRS:  EPSG:4326

# %%
# Print the geodataframe
many_places.showGeoDataFrame()
# Out:
#        0                   geometry
# 0  Vasco  POINT (40.12767 -3.22363)
# 1   Gedi  POINT (39.96239 -3.33431)

# %%
# Show webmap
many_places.webMap()

# %% [markdown]
# This class has been excitingly too long. We have already seen our `GeoSpatial` class can draw a webmap. Time for recess? Almost. But first let's stretch the lesson a bit further. Can classes inherit from another subclass, such as from `Geospatial` class as in this case? Yes. The inheritance is limitless, much like your child can beget a grandchild. We shall make this final subclass do the work of saving our webmap to the directory.

# %%
# Modules to be used in creating the class objects
import pandas as pd
import geopandas as gpd

# Classes using contextily
import contextily as cx
import matplotlib.pyplot as plt

class Place():
    """Describe our place and show it"""
    def __init__(self, names,  longitudes, latitudes): # Everything in the brackets is an argument. Self is always the first argument in a class method defintion
        self.names = names
        self.longitudes = longitudes
        self.latitudes = latitudes

    def dataTable(self):
        # Create a dataframe of names, longitudes and latitudes
        self.dataTable = pd.DataFrame({
            'Name': self.names,
            'Longitude': self.longitudes, 
            'Latitude': self.latitudes})
        
    def showDataFrame(self):
        # Prints out a neat dataframe created from dataTable above
        print(self.dataTable)
    
class GeoSpatial(Place):
    def __init__(self, names, longitudes, latitudes, crs):
        # This class is to take the arguments from Place class and use them to create a geodataframe
        super().__init__(names, longitudes, latitudes)
        self.crs = crs
        print("Name: ", self.names, "\nLongitudes: ", self.longitudes, "\nLatitudes: ", self.latitudes, "\nCRS: ", crs)
            
    def geoDataFrame(self):
        # Creates geodataframe
        self.geoDataFrame = gpd.GeoDataFrame(self.names, 
                         geometry=gpd.points_from_xy(self.longitudes, self.latitudes), 
                         crs= self.crs)
        
    def showGeoDataFrame(self):
        # Prints geodataframe
        print(self.geoDataFrame)
        
    def webMap(self):
        # Plots webmap
        fig, ax = plt.subplots(figsize=(8, 6))
        webMap = self.geoDataFrame.plot(ax=ax)
        # Here contextily plots the webmap
        cx.add_basemap(ax, crs=self.geoDataFrame.crs, source=cx.providers.OpenStreetMap.Mapnik)
        
class Map(GeoSpatial):
    def __init__(self, names, longitudes, latitudes, crs):
        super().__init__(names, longitudes, latitudes, crs)
        
    def saveMap(self, directory, dpi, orientation):
        # Saves webmap to directory
        super().geoDataFrame()
        self.directory = directory
        self.dpi = dpi
        self.orientation = orientation
        fig, ax = plt.subplots(figsize=(8, 6))
        webMap = self.geoDataFrame.plot(ax=ax)
        cx.add_basemap(ax, crs=self.geoDataFrame.crs, source=cx.providers.OpenStreetMap.Mapnik)
        
        plt.savefig(fname=self.directory, dpi=self.dpi, orientation=self.orientation)

# %% [markdown]
# Once again the `def __init__()` has been used to initialize the attributes that will go into this class. We have also used a less known trick of `super()` function. That is to [access the methods of its parent class](https://www.codingem.com/super-in-python/?utm_source=pocket_reader). In our case, for the `saveMap` method to work, it needs some of the properties of `geoDataFrame` method from the `GeoSpatial` class. It also needs the variables of `directory`, `dpi` and `orientation` for our file path, pixel resolution and relative positioning of the map respectively. The `savefig` function enables our `saveMap` method save the map into our computer's directory.

# %%
# Plot webmap and save it
many_places3 = Map(place_names, place_longitudes, place_latitudes, places_crs) #First create an instance of Map called many_place3
many_places3.saveMap("E:/documents/gis800_articles/jupyter/classes/class_map7.jpg", dpi=300, orientation='potrait')
# Out:
# Name:  ['Vasco', 'Gedi']
# Longitudes:  [40.1276701, 39.9623916]
# Latitudes:  [-3.2236304, -3.334307]
# CRS:  EPSG:4326

# %% [markdown]
# This is an extra lesson to show how to create conditional parameters inside a function. We shall create an optional parameter `facecolor` inside the `saveMap` method. The `facecolor` parameter has been assigned a default argument `0` because it is optional anywhere, and missing out the argument will result in an error. If one would like to specify a value for the `facecolor` parameter, be it a string or integer, they can do so and the `saveMap` method will happily execute their wish.

# %%
# Modules to be used in creating the class objects
import pandas as pd
import geopandas as gpd

# Classes using contextily
import contextily as cx
import matplotlib.pyplot as plt

class Place():
    """Describe our place and show it"""
    def __init__(self, names,  longitudes, latitudes): # Everything in the brackets is an argument. Self is always the first argument in a class method defintion
        self.names = names
        self.longitudes = longitudes
        self.latitudes = latitudes

    def dataTable(self):
        # Create a dataframe of names, longitudes and latitudes
        self.dataTable = pd.DataFrame({
            'Name': self.names,
            'Longitude': self.longitudes, 
            'Latitude': self.latitudes})
        
    def showDataFrame(self):
        # Prints out a neat dataframe created from dataTable above
        print(self.dataTable)
    
class GeoSpatial(Place):
    def __init__(self, names, longitudes, latitudes, crs):
        # This class is to take the arguments from Place class and use them to create a geodataframe
        super().__init__(names, longitudes, latitudes)
        self.crs = crs
        print("Name: ", self.names, "\nLongitudes: ", self.longitudes, "\nLatitudes: ", self.latitudes, "\nCRS: ", crs)
            
    def geoDataFrame(self):
        # Creates geodataframe
        self.geoDataFrame = gpd.GeoDataFrame(self.names, 
                         geometry=gpd.points_from_xy(self.longitudes, self.latitudes), 
                         crs= self.crs)
        
    def showGeoDataFrame(self):
        # Prints geodataframe
        print(self.geoDataFrame)
        
    def webMap(self):
        # Plots webmap
        fig, ax = plt.subplots(figsize=(8, 6))
        webMap = self.geoDataFrame.plot(ax=ax)
        # Here contextily plots the webmap
        cx.add_basemap(ax, crs=self.geoDataFrame.crs, source=cx.providers.OpenStreetMap.Mapnik)
        
class Map(GeoSpatial):
    def __init__(self, names, longitudes, latitudes, crs):
        super().__init__(names, longitudes, latitudes, crs)
        
    def saveMap(self, directory, dpi, orientation, facecolor='auto'): # We've set facecolor to auto to make it optional. If one want's specification, they can change the value
        super().geoDataFrame()
        self.directory = directory
        self.dpi = dpi
        self.orientation = orientation
        self.facecolor = facecolor
        fig, ax = plt.subplots(figsize=(8, 6))
        webMap = self.geoDataFrame.plot(ax=ax)
        cx.add_basemap(ax, crs=self.geoDataFrame.crs, source=cx.providers.OpenStreetMap.Mapnik)
        
        plt.savefig(fname=self.directory, dpi=self.dpi, orientation=self.orientation, facecolor=self.facecolor)

# %%
# Plot webmap with default save color values and save it
many_places4 = Map(place_names, place_longitudes, place_latitudes, places_crs) #First create an instance of Map called many_place3
many_places4.saveMap("E:/documents/gis800_articles/jupyter/classes/class_map8.jpg", dpi=300, orientation='potrait')
# Out:
# Name:  ['Vasco', 'Gedi']
# Longitudes:  [40.1276701, 39.9623916]
# Latitudes:  [-3.2236304, -3.334307]
# CRS:  EPSG:4326

# %%
# Plot webmap with custom facecolor values and save it
many_places5 = Map(place_names, place_longitudes, place_latitudes, places_crs) #First create an instance of Map called many_place3
many_places5.saveMap("E:/documents/gis800_articles/jupyter/classes/class_map8.jpg", dpi=300, orientation='potrait', facecolor='yellow')
# Out:
# Name:  ['Vasco', 'Gedi']
# Longitudes:  [40.1276701, 39.9623916]
# Latitudes:  [-3.2236304, -3.334307]
# CRS:  EPSG:4326

# %% [markdown]
# This is how our custom 'facecolored' map appears. Yellow yell no!

# %%
from IPython import display
display.Image("E:documents/gis800_articles/jupyter/classes/class_map8.jpg", 
             alt="This is how a yellow facecolor looks!",
             width=800,
             height=600)

# %% [markdown]
# # Conclusion
#
# Classes and objects are the backbone of python. A major advantage of classes is that they can be reused. They contain many methods that can be used to extract particular information from the object under inquiry. They also shorten the code compared to if `if/else/elif` were used. In this exercise we showed how classes and objects can be used in a spatial operation to print out dataframes, form and print geodataframes, print and likewise save webMaps! You will have noted that classes have brought structure to what would have been a mixmash of code.
#
# However, for one to become a guru in Python, you will need to master the following concepts:
#
# <ol>
#     <li>The `def __init__()` function</li>
#     <li>Inheritance</li>
#     <li>Super().__init__()</li>
#     <li>Class attributes</li>
#     <li>Class arguments</li>
#     <li>Class attributes</li>
#     <li>Instance attributes</li>
# </ol>
#
# If you excel in this class of Python classes, consider yourself dangerous.
